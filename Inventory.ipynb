# %%
data = {1001: {"Name":"Maggie", "Quantity":15, "Price":10, "Manufacture date":"21-10-2020", "Best Before":"15-10-2021"},
        1002: {"Name":"Parle Rusk", "Quantity":19, "Price":32, "Manufacture date":"10-11-2020", "Best Before":"11-9-2021"},
        1003: {"Name":"Colgate", "Quantity":10, "Price":109, "Manufacture date":"8-2-2021", "Best Before":"23-12-2021"},
        1004: {"Name":"Tata Salt", "Quantity":21, "Price":30, "Manufacture date":"20-3-2021", "Best Before":"10-10-2022"},
        1005: {"Name":"Lizol Disinfectant", "Quantity":12, "Price":329, "Manufacture date":"6-8-2021", "Best Before":"14-3-2021"},
        1006: {"Name":"Unibic Cookies", "Quantity":15, "Price":66, "Manufacture date":"1-10-2020", "Best Before":"12-9-2021"},
        1007: {"Name":"Aashirvaad Atta", "Quantity":25, "Price":240, "Manufacture date":"15-7-2021", "Best Before":"10-12-2021"},
        1008: {"Name":"Lux Soap", "Quantity":40, "Price":280, "Manufacture date":"19-8-2020", "Best Before":"15-12-2021"},
        1009: {"Name":"Tide Bar", "Quantity":30, "Price":30, "Manufacture date":"16-12-2020", "Best Before":"21-9-2021"},
        1010: {"Name":"Pears Soap", "Quantity":35, "Price":432, "Manufacture date":"15-5-2021", "Best Before":"10-11-2022"},
        1011: {"Name":"Dabur Honey", "Quantity":45, "Price":250, "Manufacture date":"2-3-2021", "Best Before":"31-12-2021"},
        1012: {"Name":"Saffola Honey", "Quantity":40, "Price":242, "Manufacture date":"5-2-2020", "Best Before":"12-11-2021"},
        1013: {"Name":"Ariel Detergent", "Quantity":30, "Price":300, "Manufacture date":"8-1-2020", "Best Before":"16-11-2021"},
        1014: {"Name":"Bournvita Health Drink", "Quantity":40, "Price":210, "Manufacture date":"10-5-2021", "Best Before":"25-11-2021"},
        1015: {"Name":"Dettol Handwash", "Quantity":50, "Price":198, "Manufacture date":"7-7-2021", "Best Before":"28-10-2021"},
        1016: {"Name":"Parachute Oil", "Quantity":45, "Price":255, "Manufacture date":"9-12-2020", "Best Before":"2-9-2021"},
        1017: {"Name":"Santoor Soap", "Quantity":30, "Price":40, "Manufacture date":"10-4-2021", "Best Before":"20-12-2021"},
        1018: {"Name":"Sunsilk Shampoo", "Quantity":44, "Price":270, "Manufacture date":"14-3-2021", "Best Before":"6-4-2022"},
        1019: {"Name":"Sunfeast Cookies", "Quantity":52, "Price":80, "Manufacture date":"8-6-2021", "Best Before":"25-9-2021"},
        1020: {"Name":"Sensodyne Toothpaste", "Quantity":25, "Price":180, "Manufacture date":"24-5-2021", "Best Before":"19-10-2022"},
        1021: {"Name":"Cinthol Soap", "Quantity":38, "Price":150, "Manufacture date":"20-6-2020", "Best Before":"15-19-2021"},
        1022: {"Name":"Tata Tea", "Quantity":45, "Price":270, "Manufacture date":"2-6-2021", "Best Before":"12-10-2021"},
        1023: {"Name":"Medimix Soap", "Quantity":35, "Price":120, "Manufacture date":"18-12-2020", "Best Before":"22-10-2021"},
        1024: {"Name":"Lays", "Quantity":55, "Price":10, "Manufacture date":"26-5-2021", "Best Before":"20-11-2021"},
        1025: {"Name":"Parle Biscuit", "Quantity":52, "Price":30, "Manufacture date":"14-7-2021", "Best Before":"10-12-2021"},
        1026: {"Name":"Vim Dishwash Bar", "Quantity":45, "Price":40, "Manufacture date":"9-10-2020", "Best Before":"17-9-2021"},
        1027: {"Name":"Parle Cheeselings", "Quantity":58, "Price":55, "Manufacture date":"12-5-2021", "Best Before":"4-12-2021"},
        1028: {"Name":"Loreal Shampoo", "Quantity":30, "Price":480, "Manufacture date":"9-8-2020", "Best Before":"1-8-2022"},
        1029: {"Name":"Nivea Face Wash", "Quantity":50, "Price":170, "Manufacture date":"11-5-2020", "Best Before":"1-3-2022"},
        1030: {"Name":"Plum Face Wash", "Quantity":40, "Price":330, "Manufacture date":"6-1-2020", "Best Before":"21-8-2021"}}

# %%
import json
js = json.dumps(data)
a = open("records.json",'w')
a.write(js)
a.close()

# %%
b = open("records.json",'r')
text = b.read()
b.close()
info = json.loads(text)

# %%
#Bill

ID = int(input("Enter product ID: "))
quan = int(input("Enter product quantity: "))

for i in data:
  if data[ID] == data[i] and data[i]['Quantity']>0:
    print("*******************************")
    print("Product name: ",data[i]['Name'])
    print("Product price: ",str(data[i]['Price']))
    print("Manufacture date: ",data[i]['Manufacture date'])
    print("Best before: ",data[i]['Best Before'])
    print("*******************************")
    print("Total amount: ",str(data[i]['Price']*quan))
    data[i]['Quantity'] = data[i]['Quantity'] - quan
# Out:
# Enter product ID: 1005
# Enter product quantity: 1
# *******************************
# Product name:  Lizol Disinfectant
# Product price:  329
# Manufacture date:  6-8-2021
# Best before:  14-3-2021
# *******************************
# Total amount:  329

# %%
js = json.dumps(data)
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
data
# Out:
# {1001: {'Best Before': '15-10-2021',
#   'Manufacture date': '21-10-2020',
#   'Name': 'Maggie',
#   'Price': 10,
#   'Quantity': 15},
#  1002: {'Best Before': '11-9-2021',
#   'Manufacture date': '10-11-2020',
#   'Name': 'Parle Rusk',
#   'Price': 32,
#   'Quantity': 19},
#  1003: {'Best Before': '23-12-2021',
#   'Manufacture date': '8-2-2021',
#   'Name': 'Colgate',
#   'Price': 109,
#   'Quantity': 8},
#  1004: {'Best Before': '10-10-2022',
#   'Manufacture date': '20-3-2021',
#   'Name': 'Tata Salt',
#   'Price': 30,
#   'Quantity': 21},
#  1005: {'Best Before': '14-3-2021',
#   'Manufacture date': '6-8-2021',
#   'Name': 'Lizol Disinfectant',
#   'Price': 329,
#   'Quantity': 11},
#  1006: {'Best Before': '12-9-2021',
#   'Manufacture date': '1-10-2020',
#   'Name': 'Unibic Cookies',
#   'Price': 66,
#   'Quantity': 15},
#  1007: {'Best Before': '10-12-2021',
#   'Manufacture date': '15-7-2021',
#   'Name': 'Aashirvaad Atta',
#   'Price': 240,
#   'Quantity': 25},
# ...

# %%
#Add a product in the inventory

Prod_ID = int(input("Enter product ID: "))
name = str(input("Enter product name: "))
quant = int(input("Enter product quantity: "))
pri = int(input("Enter product price: "))
manufacture = str(input("Enter manufacturing date: "))
best_before = str(input("Enter Best Before date: "))

data[Prod_ID] = {'Name':name, 'Quantity':quant, 'Price':pri, "Manufacture date":manufacture, "Best Before":best_before}

js = json.dumps(data)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product ID: 1031
# Enter product name: Medimix Soap
# Enter product quantity: 46
# Enter product price: 67
# Enter manufacturing date: 8-3-2020
# Enter Best Before date: 13-5-2021

# %%
data
# Out:
# {1001: {'Best Before': '15-10-2021',
#   'Manufacture date': '21-10-2020',
#   'Name': 'Maggie',
#   'Price': 10,
#   'Quantity': 15},
#  1002: {'Best Before': '11-9-2021',
#   'Manufacture date': '10-11-2020',
#   'Name': 'Parle Rusk',
#   'Price': 32,
#   'Quantity': 19},
#  1003: {'Best Before': '23-12-2021',
#   'Manufacture date': '8-2-2021',
#   'Name': 'Colgate',
#   'Price': 109,
#   'Quantity': 8},
#  1004: {'Best Before': '10-10-2022',
#   'Manufacture date': '20-3-2021',
#   'Name': 'Tata Salt',
#   'Price': 30,
#   'Quantity': 21},
#  1005: {'Best Before': '14-3-2021',
#   'Manufacture date': '6-8-2021',
#   'Name': 'Lizol Disinfectant',
#   'Price': 329,
#   'Quantity': 12},
#  1006: {'Best Before': '12-9-2021',
#   'Manufacture date': '1-10-2020',
#   'Name': 'Unibic Cookies',
#   'Price': 66,
#   'Quantity': 15},
#  1007: {'Best Before': '10-12-2021',
#   'Manufacture date': '15-7-2021',
#   'Name': 'Aashirvaad Atta',
#   'Price': 240,
#   'Quantity': 25},
# ...
